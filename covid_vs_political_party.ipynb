# %% [markdown]
# ## Ruling political parties

# %%
import requests
import pandas as pd
import numpy as np
# website_url = requests.get('https://en.wikipedia.org/wiki/List_of_current_heads_of_state_and_government').text
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_ruling_political_parties_by_country').text

# %%
# !pip install lxml

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(website_url,'lxml')

# %%
# List of Tuples
table_list = [ ]
for table in soup.find_all('table', class_='wikitable'):
    for row in table.find_all('tr')[2:]:
        data = row.find_all(['th','td'])
        if data[1].a.text == 'United Arab Emirates':
            country = data[1].a.text
            party = 'Federal National Council'
            party_link = '/wiki/Politics_of_the_United_Arab_Emirates'
            table_list.append((country,party,party_link))
        elif len(data) == 8:
            try:
                country = data[1].a.text
                party = data[6].a.text
                party_link = data[6].a['href']
            except IndexError:pass
            except AttributeError:pass
            if country != '':
                table_list.append((country,party,party_link))
#Create a DataFrame object
countries = pd.DataFrame(table_list, columns=['Country', 'Ruling Party', 'Link'])

# %%
countries.tail(20)
# Out:
#                                  Country  \
# 199                               Turkey
# 200                         Turkmenistan
# 201                     Turks and Caicos
# 202                               Uganda
# 203                              Ukraine
# 204                 United Arab Emirates
# 205                       United Kingdom
# 206                     Northern Ireland
# 207                        United States
# 208                              Uruguay
# 209                           Uzbekistan
# 210                              Vanuatu
# 211                            Venezuela
# 212                              Vietnam
# 213  Virgin Islands of the United States
# 214                    Wallis and Futuna
# 215                       Western Sahara
# 216                                Yemen
# 217                               Zambia
# 218                             Zimbabwe
#
#                                           Ruling Party  \
# 199                      Justice and Development Party
# 200                   Democratic Party of Turkmenistan
# 201                       People's Democratic Movement
# 202                       National Resistance Movement
# 203                              Servant of the People
# 204                           Federal National Council
# 205                                 Conservative Party
# 206                                                DUP
# 207                                   Republican Party
# 208                                     National Party
# 209                Uzbekistan Liberal Democratic Party
# 210                  Reunification Movement for Change
# 211                United Socialist Party of Venezuela
# 212                         Communist Party of Vietnam
# 213             Democratic Party of the Virgin Islands
# 214             Democratic Party of the Virgin Islands
# 215                                    Polisario Front
# 216                          General People's Congress
# 217                                    Patriotic Front
# 218  Zimbabwe African National Union – Patriotic Front
#
#                                                   Link
# 199       /wiki/Justice_and_Development_Party_(Turkey)
# 200             /wiki/Democratic_Party_of_Turkmenistan
# 201  /wiki/People%27s_Democratic_Movement_(Turks_an...
# 202                 /wiki/National_Resistance_Movement
# 203      /wiki/Servant_of_the_People_(political_party)
# 204         /wiki/Politics_of_the_United_Arab_Emirates
# 205                      /wiki/Conservative_Party_(UK)
# 206                    /wiki/Democratic_Unionist_Party
# 207             /wiki/Republican_Party_(United_States)
# 208                     /wiki/National_Party_(Uruguay)
# 209          /wiki/Uzbekistan_Liberal_Democratic_Party
# 210            /wiki/Reunification_Movement_for_Change
# 211          /wiki/United_Socialist_Party_of_Venezuela
# 212                   /wiki/Communist_Party_of_Vietnam
# 213       /wiki/Democratic_Party_of_the_Virgin_Islands
# 214       /wiki/Democratic_Party_of_the_Virgin_Islands
# 215                              /wiki/Polisario_Front
# 216          /wiki/General_People%27s_Congress_(Yemen)
# 217                     /wiki/Patriotic_Front_(Zambia)
# 218  /wiki/Zimbabwe_African_National_Union_%E2%80%9...

# %%
politics = {}
for index, country in countries.iterrows():
    link = country['Link']
    party_url = requests.get(f'https://en.wikipedia.org{link}').text
    party_soup = BeautifulSoup(party_url,'lxml')
    table = party_soup.find('table', class_='infobox vcard')
    if table != None:
        for row in table.find_all('tr'):
            try:
                if row.a.text == 'Political\xa0position':
                    data = row.find_all(['th','td'])
                    try:
                        spectrum = data[1].find_all('a')
                        pp = []
                        for word in spectrum:
                            if word.text[0] != '[' and word.text != 'citation needed':
                                pp.append(word.text)
                        political_position = pp
                    except IndexError:pass
                    except AttributeError:pass
                    politics[country['Country']] = political_position
                    break
            except:
                pass

# %%
not_found = set(countries['Country']) - set(politics.keys()) # to be scraped independently/manually
not_found
# Out:
# {'Afghanistan',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'British Virgin Islands',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'China',
#  'Comoros',
#  'Cook Islands',
#  'Equatorial Guinea',
#  'French Guiana',
#  'Gambia',
#  'Guatemala',
#  'Guyana',
#  'Hong Kong',
#  'Italy',
#  'Kiribati',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Macau',
#  'Madagascar',
#  'Marshall Islands',
#  'Montserrat',
#  'Morocco',
#  'New Caledonia',
#  'Papua New Guinea',
#  'Russia',
#  'Saint Kitts and Nevis',
#  'Sint Maarten',
#  'Solomon Islands',
#  'South Sudan',
#  'Sudan',
#  'Tajikistan',
#  'United Arab Emirates',
#  'United States',
#  'Vanuatu',
#  'Virgin Islands of the United States',
#  'Wallis and Futuna'}

# %%
politics['Italy'] = ['Centre-left'] # (rough average of parties) source:https://en.wikipedia.org/wiki/Conte_II_Cabinet
politics['United States'] = ['Centre-right','right-wing'] # (position of European affiliation) source:https://en.wikipedia.org/wiki/Republican_Party_(United_States)
# politics['Russia'] = ['Big tent'] # (parliament) source: https://en.wikipedia.org/wiki/United_Russia
politics['Cameroon'] = ['Big tent'] # https://en.wikipedia.org/wiki/Cameroon_People%27s_Democratic_Movement
politics['Jamaica'] = ['Centre-right'] # https://en.wikipedia.org/wiki/Jamaica_Labour_Party

# %%
# Include list of dictatorships as a political position on their own:
dictatorship_url = requests.get('https://worldpopulationreview.com/countries/dictatorship-countries/').text

# %%
soup = BeautifulSoup(dictatorship_url,'lxml')

# %%
dictatorship_countries = [country.text for country in soup.find_all('ul')[2].find_all('a')]
dictatorship_countries.extend(['Algeria', 'Equatorial Guinea', 'North Korea', 'Sudan']) 
# should maybe add Brazil, Hungary and Poland
len(dictatorship_countries)
# Out:
# 49

# %%
len(politics.keys())
# Out:
# 182

# %%
for state in dictatorship_countries:
    politics[state] = ['Dictatorship']
len(politics.keys())
# Out:
# 202

# %%
countries['Political Position']= countries['Country'].map(politics)

# %%
countries.tail(20)
# Out:
#                                  Country  \
# 199                               Turkey
# 200                         Turkmenistan
# 201                     Turks and Caicos
# 202                               Uganda
# 203                              Ukraine
# 204                 United Arab Emirates
# 205                       United Kingdom
# 206                     Northern Ireland
# 207                        United States
# 208                              Uruguay
# 209                           Uzbekistan
# 210                              Vanuatu
# 211                            Venezuela
# 212                              Vietnam
# 213  Virgin Islands of the United States
# 214                    Wallis and Futuna
# 215                       Western Sahara
# 216                                Yemen
# 217                               Zambia
# 218                             Zimbabwe
#
#                                           Ruling Party  \
# 199                      Justice and Development Party
# 200                   Democratic Party of Turkmenistan
# 201                       People's Democratic Movement
# 202                       National Resistance Movement
# 203                              Servant of the People
# 204                           Federal National Council
# 205                                 Conservative Party
# 206                                                DUP
# 207                                   Republican Party
# 208                                     National Party
# 209                Uzbekistan Liberal Democratic Party
# 210                  Reunification Movement for Change
# 211                United Socialist Party of Venezuela
# 212                         Communist Party of Vietnam
# 213             Democratic Party of the Virgin Islands
# 214             Democratic Party of the Virgin Islands
# 215                                    Polisario Front
# 216                          General People's Congress
# 217                                    Patriotic Front
# 218  Zimbabwe African National Union – Patriotic Front
#
#                                                   Link  \
# 199       /wiki/Justice_and_Development_Party_(Turkey)
# 200             /wiki/Democratic_Party_of_Turkmenistan
# 201  /wiki/People%27s_Democratic_Movement_(Turks_an...
# 202                 /wiki/National_Resistance_Movement
# 203      /wiki/Servant_of_the_People_(political_party)
# 204         /wiki/Politics_of_the_United_Arab_Emirates
# 205                      /wiki/Conservative_Party_(UK)
# 206                    /wiki/Democratic_Unionist_Party
# 207             /wiki/Republican_Party_(United_States)
# 208                     /wiki/National_Party_(Uruguay)
# 209          /wiki/Uzbekistan_Liberal_Democratic_Party
# 210            /wiki/Reunification_Movement_for_Change
# 211          /wiki/United_Socialist_Party_of_Venezuela
# 212                   /wiki/Communist_Party_of_Vietnam
# 213       /wiki/Democratic_Party_of_the_Virgin_Islands
# 214       /wiki/Democratic_Party_of_the_Virgin_Islands
# 215                              /wiki/Polisario_Front
# 216          /wiki/General_People%27s_Congress_(Yemen)
# 217                     /wiki/Patriotic_Front_(Zambia)
# 218  /wiki/Zimbabwe_African_National_Union_%E2%80%9...
#
#              Political Position
# 199              [Dictatorship]
# 200              [Dictatorship]
# 201                    [Centre]
# 202              [Dictatorship]
# 203                  [Big tent]
# 204              [Dictatorship]
# 205              [Centre-right]
# 206  [Centre-right, right-wing]
# 207  [Centre-right, right-wing]
# 208    [Centre-right, centrist]
# 209              [Dictatorship]
# 210                         NaN
# 211              [Dictatorship]
# 212              [Dictatorship]
# 213                         NaN
# 214                         NaN
# 215              [Dictatorship]
# 216              [Dictatorship]
# 217               [Centre-left]
# 218                 [Left-wing]

# %%
countries.dropna(inplace=True)
countries.shape
# Out:
# (193, 4)

# %%
# countries.set_index('Country')

# %%
# print(countries['Political Position'].nunique())
# countries['Political Position'].drop_duplicates()

# %%
set([item for sublist in list(countries['Political Position'].values) for item in sublist]) # unique values
# Out:
# {'Big tent',
#  'Center',
#  'Center-left',
#  'Center-right',
#  'Centre',
#  'Centre-left',
#  'Centre-right',
#  'Dictatorship',
#  'Far-left',
#  'Left-wing',
#  'Right-wing',
#  'centre-left',
#  'centre-right',
#  'centrist',
#  'far-left',
#  'far-right',
#  'left-wing',
#  'right-wing'}

# %%
poli_to_number = {'Dictatorship': -1,
                 'Big tent': 0,
                 'Far-left': 1,
                 'far-left': 1,
                 'Left-wing': 2,
                 'Left wing': 2,
                 'left-wing': 2,
                 'Centre-left': 3,
                 'Center-left': 3,
                 'centre-left': 3,
                 'Center': 4,
                 'centrist': 4,
                 'Centre': 4,
                 'Centre-right': 5,
                 'Center-right': 5,
                 'centre-right': 5,
                 'Right-wing': 6,
                 'Right wing': 6,
                 'right-wing': 6,
                 'far-right': 7 }

# %%
def turn_list_to_number(poli_list):
    numbers = []
    for item in poli_list:
        if item != 'Big tent': # how to account for Big tent in average?
            numbers.append(poli_to_number[item])
    if len(numbers) == 0: # if Big tent is the only party
        return 0
    return sum(numbers) / len(numbers)

# %%
countries['poli_numbers'] = countries['Political Position'].apply(lambda x: turn_list_to_number(x))

# %%
countries
# Out:
#             Country                                       Ruling Party  \
# 0       Afghanistan                                        Independent
# 1             Åland                                  Liberals of Åland
# 2           Albania                         Socialist Party of Albania
# 3           Algeria                          National Liberation Front
# 4           Andorra                              Democrats for Andorra
# ..              ...                                                ...
# 212         Vietnam                         Communist Party of Vietnam
# 215  Western Sahara                                    Polisario Front
# 216           Yemen                          General People's Congress
# 217          Zambia                                    Patriotic Front
# 218        Zimbabwe  Zimbabwe African National Union – Patriotic Front
#
#                                                   Link  \
# 0                         /wiki/Independent_politician
# 1                         /wiki/Liberals_of_%C3%85land
# 2                     /wiki/Socialist_Party_of_Albania
# 3            /wiki/National_Liberation_Front_(Algeria)
# 4                          /wiki/Democrats_for_Andorra
# ..                                                 ...
# 212                   /wiki/Communist_Party_of_Vietnam
# 215                              /wiki/Polisario_Front
# 216          /wiki/General_People%27s_Congress_(Yemen)
# 217                     /wiki/Patriotic_Front_(Zambia)
# 218  /wiki/Zimbabwe_African_National_Union_%E2%80%9...
#
#            Political Position  poli_numbers
# 0              [Dictatorship]          -1.0
# 1                    [Centre]           4.0
# 2    [Centre-left, left-wing]           2.5
# 3              [Dictatorship]          -1.0
# 4              [Centre-right]           5.0
# ..                        ...           ...
# 212            [Dictatorship]          -1.0
# 215            [Dictatorship]          -1.0
# 216            [Dictatorship]          -1.0
# 217             [Centre-left]           3.0
# 218               [Left-wing]           2.0
#
# [193 rows x 5 columns]

# %%
# countries.to_csv('filtered_countries.csv') # Last saved: 10 May 20

# %%
countries = pd.read_csv('filtered_countries.csv', index_col=0)

# %% [markdown]
# ## Updated covid data

# %%
covid = pd.read_csv("https://opendata.ecdc.europa.eu/covid19/casedistribution/csv", na_values = "", encoding = "utf-8")

# %%
covid
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      31/05/2020   31      5  2020    866       3             Afghanistan
# 1      30/05/2020   30      5  2020    623      11             Afghanistan
# 2      29/05/2020   29      5  2020    580       8             Afghanistan
# 3      28/05/2020   28      5  2020    625       7             Afghanistan
# 4      27/05/2020   27      5  2020    658       1             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 20497  25/03/2020   25      3  2020      0       0                Zimbabwe
# 20498  24/03/2020   24      3  2020      0       1                Zimbabwe
# 20499  23/03/2020   23      3  2020      0       0                Zimbabwe
# 20500  22/03/2020   22      3  2020      1       0                Zimbabwe
# 20501  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2018 continentExp
# 0        AF                  AFG   37172386.0         Asia
# 1        AF                  AFG   37172386.0         Asia
# 2        AF                  AFG   37172386.0         Asia
# 3        AF                  AFG   37172386.0         Asia
# 4        AF                  AFG   37172386.0         Asia
# ...     ...                  ...          ...          ...
# 20497    ZW                  ZWE   14439018.0       Africa
# 20498    ZW                  ZWE   14439018.0       Africa
# 20499    ZW                  ZWE   14439018.0       Africa
# 20500    ZW                  ZWE   14439018.0       Africa
# 20501    ZW                  ZWE   14439018.0       Africa
#
# [20502 rows x 11 columns]

# %%
covid.groupby('countriesAndTerritories').sum()[['cases', 'deaths']].loc['Italy'] # sanity check
# Out:
# cases     232664
# deaths     33340
# Name: Italy, dtype: int64

# %%
covid.groupby('countriesAndTerritories').sum()[['cases', 'deaths']].loc['United_Kingdom'] # sanity check
# Out:
# cases     272826
# deaths     38376
# Name: United_Kingdom, dtype: int64

# %%
cases_deaths = covid.groupby('countriesAndTerritories').sum()[['cases', 'deaths']]

# %%
population = covid[['countriesAndTerritories', 'popData2018', 'continentExp']
                  ].drop_duplicates().set_index('countriesAndTerritories')
population.columns = ['population2018', 'continent']

# %%
cov_table = pd.concat([cases_deaths, population], axis=1)

# %%
cov_table.dropna(inplace=True)
cov_table.shape
# Out:
# (205, 4)

# %%
cov_table['%cases'] = cov_table['cases']/cov_table['population2018']
cov_table['%deaths'] = cov_table['deaths']/cov_table['population2018']
cov_table['mortality'] = cov_table['deaths']/cov_table['cases']

# %%
spaced_names = [' '.join((name).split('_')) for name in cov_table.index]
cov_table.index = spaced_names
cov_table.tail(10)
# Out:
#                                 cases  deaths  population2018 continent  \
# United Republic of Tanzania       509      21      56318348.0    Africa
# United States Virgin Islands       69       6        106977.0   America
# United States of America      1770384  103781     327167434.0   America
# Uruguay                           821      22       3449299.0   America
# Uzbekistan                       3554      14      32955400.0      Asia
# Venezuela                        1459      14      28870195.0   America
# Vietnam                           327       0      95540395.0      Asia
# Yemen                             310      77      28498687.0      Asia
# Zambia                           1057       7      17351822.0    Africa
# Zimbabwe                          174       4      14439018.0    Africa
#
#                                 %cases       %deaths  mortality
# United Republic of Tanzania   0.000009  3.728803e-07   0.041257
# United States Virgin Islands  0.000645  5.608682e-05   0.086957
# United States of America      0.005411  3.172107e-04   0.058621
# Uruguay                       0.000238  6.378108e-06   0.026797
# Uzbekistan                    0.000108  4.248166e-07   0.003939
# Venezuela                     0.000051  4.849292e-07   0.009596
# Vietnam                       0.000003  0.000000e+00   0.000000
# Yemen                         0.000011  2.701879e-06   0.248387
# Zambia                        0.000061  4.034158e-07   0.006623
# Zimbabwe                      0.000012  2.770271e-07   0.022989

# %%
cov_table.rename(index={'United States of America':'United States', 'Czechia':'Czech Republic', 
                        'Guinea Bissau': 'Guinea-Bissau', "Cote dIvoire": "Côte d'Ivoire" },inplace=True)
cov_table.tail(10)
# Out:
#                                 cases  deaths  population2018 continent  \
# United Republic of Tanzania       509      21      56318348.0    Africa
# United States Virgin Islands       69       6        106977.0   America
# United States                 1770384  103781     327167434.0   America
# Uruguay                           821      22       3449299.0   America
# Uzbekistan                       3554      14      32955400.0      Asia
# Venezuela                        1459      14      28870195.0   America
# Vietnam                           327       0      95540395.0      Asia
# Yemen                             310      77      28498687.0      Asia
# Zambia                           1057       7      17351822.0    Africa
# Zimbabwe                          174       4      14439018.0    Africa
#
#                                 %cases       %deaths  mortality
# United Republic of Tanzania   0.000009  3.728803e-07   0.041257
# United States Virgin Islands  0.000645  5.608682e-05   0.086957
# United States                 0.005411  3.172107e-04   0.058621
# Uruguay                       0.000238  6.378108e-06   0.026797
# Uzbekistan                    0.000108  4.248166e-07   0.003939
# Venezuela                     0.000051  4.849292e-07   0.009596
# Vietnam                       0.000003  0.000000e+00   0.000000
# Yemen                         0.000011  2.701879e-06   0.248387
# Zambia                        0.000061  4.034158e-07   0.006623
# Zimbabwe                      0.000012  2.770271e-07   0.022989

# %%
# !conda install -c bokeh bokeh -y

# %% [markdown]
# ## Putting it all together

# %%
country_parties = countries.set_index('Country')[['Ruling Party', 'poli_numbers']]
country_parties.tail()
# Out:
#                                                      Ruling Party  \
# Country
# Vietnam                                Communist Party of Vietnam
# Western Sahara                                    Polisario Front
# Yemen                                   General People's Congress
# Zambia                                            Patriotic Front
# Zimbabwe        Zimbabwe African National Union – Patriotic Front
#
#                 poli_numbers
# Country
# Vietnam                 -1.0
# Western Sahara          -1.0
# Yemen                   -1.0
# Zambia                   3.0
# Zimbabwe                 2.0

# %%
cov_table.index.rename('Country', inplace=True)
cov_table.tail()
# Out:
#            cases  deaths  population2018 continent    %cases       %deaths  \
# Country
# Venezuela   1459      14      28870195.0   America  0.000051  4.849292e-07
# Vietnam      327       0      95540395.0      Asia  0.000003  0.000000e+00
# Yemen        310      77      28498687.0      Asia  0.000011  2.701879e-06
# Zambia      1057       7      17351822.0    Africa  0.000061  4.034158e-07
# Zimbabwe     174       4      14439018.0    Africa  0.000012  2.770271e-07
#
#            mortality
# Country
# Venezuela   0.009596
# Vietnam     0.000000
# Yemen       0.248387
# Zambia      0.006623
# Zimbabwe    0.022989

# %%
full_table = pd.concat([country_parties, cov_table], axis=1, join='inner')
full_table.tail()
# Out:
#                                                 Ruling Party  poli_numbers  \
# Country
# Venezuela                United Socialist Party of Venezuela          -1.0
# Vietnam                           Communist Party of Vietnam          -1.0
# Yemen                              General People's Congress          -1.0
# Zambia                                       Patriotic Front           3.0
# Zimbabwe   Zimbabwe African National Union – Patriotic Front           2.0
#
#            cases  deaths  population2018 continent    %cases       %deaths  \
# Country
# Venezuela   1459      14      28870195.0   America  0.000051  4.849292e-07
# Vietnam      327       0      95540395.0      Asia  0.000003  0.000000e+00
# Yemen        310      77      28498687.0      Asia  0.000011  2.701879e-06
# Zambia      1057       7      17351822.0    Africa  0.000061  4.034158e-07
# Zimbabwe     174       4      14439018.0    Africa  0.000012  2.770271e-07
#
#            mortality
# Country
# Venezuela   0.009596
# Vietnam     0.000000
# Yemen       0.248387
# Zambia      0.006623
# Zimbabwe    0.022989

# %%
country_parties.shape
# Out:
# (193, 2)

# %%
full_table.shape
# Out:
# (169, 9)

# %%
set(country_parties.index) - set(full_table.index) # checking non matching countries (covid data unavailable)
# Out:
# {'Artsakh',
#  'Bonaire',
#  'Burma',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'East Timor',
#  'Eritrea',
#  'European Union',
#  'Guadeloupe',
#  'Mayotte',
#  'Nauru',
#  'North Korea',
#  'Northern Cyprus',
#  'Northern Ireland',
#  'Saint Helena',
#  'Saint Pierre and Miquelon',
#  'Samoa',
#  'São Tomé and Príncipe',
#  'Tanzania',
#  'Transnistria',
#  'Turkmenistan',
#  'Turks and Caicos',
#  'Western Sahara',
#  'Åland'}

# %%
set(cov_table.index) - set(full_table.index) # non matching countries (political data unavailable)
# Out:
# {'Antigua and Barbuda',
#  'Bahrain',
#  'Belarus',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Cases on an international conveyance Japan',
#  'Comoros',
#  'Congo',
#  'Democratic Republic of the Congo',
#  'Eswatini',
#  'Gambia',
#  'Guam',
#  'Guatemala',
#  'Guernsey',
#  'Guyana',
#  'Holy See',
#  'Kuwait',
#  'Liberia',
#  'Madagascar',
#  'Montserrat',
#  'Morocco',
#  'Myanmar',
#  'New Caledonia',
#  'Northern Mariana Islands',
#  'Oman',
#  'Papua New Guinea',
#  'Qatar',
#  'Saint Kitts and Nevis',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Sint Maarten',
#  'Timor Leste',
#  'Turks and Caicos islands',
#  'United Republic of Tanzania',
#  'United States Virgin Islands'}

# %%
full_table.poli_numbers.max()
# Out:
# 6.5

# %%
numbers_to_poli = {v: (k[0].upper() + k[1:]) for k,v in poli_to_number.items()}
numbers_to_poli
# Out:
# {-1: 'Dictatorship',
#  0: 'Big tent',
#  1: 'Far-left',
#  2: 'Left-wing',
#  3: 'Centre-left',
#  4: 'Centre',
#  5: 'Centre-right',
#  6: 'Right-wing',
#  7: 'Far-right'}

# %%
full_table.rename(columns={'Ruling Party': 'ruling_party'}, inplace=True)

# %%
# Bokeh Libraries
from bokeh.io import output_file, output_notebook, export_png
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
from bokeh.models import ColumnDataSource, NumeralTickFormatter
from bokeh.layouts import gridplot

# output_file('filename.html')  # Render to static HTML, or 
output_notebook()  # Render inline in a Jupyter Notebook

def scatter_plot(y_axis_column: str = '%cases'):
    for i in range(2,4):
        if full_table[y_axis_column].values.max().round(decimals=i) > 0:
            if full_table[y_axis_column].values.max() < full_table[y_axis_column].values.max().round(decimals=i):
                max_y = full_table[y_axis_column].values.max().round(decimals=i)
            else:
                max_y = full_table[y_axis_column].values.max().round(decimals=i) + 0.5*10**(-i)
            break
    # Store the data in a ColumnDataSource
    covid_data = ColumnDataSource(full_table)

    # output_file(f'{y_axis_column} table.html', title=f'{y_axis_column} table')
    
    if y_axis_column == 'mortality':
        title_string = f'{y_axis_column} by ruling political party'
    else:
        title_string = f'% of {y_axis_column[1:]} by ruling political party'
    # Create a figure with no toolbar and axis ranges of [0,3]
    fig = figure(title=title_string,
                 plot_height=800, plot_width=800,
                 x_range=(-1.5, 7), y_range=(0, max_y),
                 x_axis_label='Political Position')

    # Format the tooltip
    tooltips = [
                ('Country','@Country'),
                ('Ruling Party', '@ruling_party')
        # TODO add numeric value
               ]

    # Draw the coordinates as circles
    fig.circle(x='poli_numbers', y=y_axis_column, size=10, alpha=0.5, source=covid_data)


    # Add the HoverTool to the figure
    fig.add_tools(HoverTool(tooltips=tooltips))
    
    # Format the y-axis tick labels
    fig.yaxis[0].formatter = NumeralTickFormatter(format='0.0000')
    
    # Custom labels for xaxis
    fig.xaxis.ticker = list(numbers_to_poli.keys())
    fig.xaxis.major_label_overrides = numbers_to_poli
    # Show plot
#     show(fig)
    return fig
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1824">Loading BokehJS ...</span>
#     </div>

# %%
cases = scatter_plot()

# %%
deaths = scatter_plot('%deaths')

# %%
mortality = scatter_plot('mortality')

# %%
# !conda install selenium -y

# %%
output_file("covid-by-country.html", title="Covid visualization by country")

output_notebook()
gplot=gridplot([cases, deaths, mortality], sizing_mode='stretch_both', ncols=3)#, plot_width=800, plot_height=600)
show(gplot)  # open a browser
# export_png(gplot, filename="covid-by-country.png")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3618">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b9e86cf3-1f03-45da-8398-0d5d44dfebbb" data-root-id="3643"></div>

# %% [markdown]
# ## Statistical Analysis
# Work in progress

# %%
sample_sizes = full_table.groupby('poli_numbers').count()['ruling_party']
keep_samples = sample_sizes[sample_sizes >= 10].rename('sample sizes')

# %%
keep_samples.index
# Out:
# Float64Index([-1.0, 2.5, 3.0, 4.0, 4.5, 5.0, 5.5, 6.0], dtype='float64', name='poli_numbers')

# %%
subsample_table = full_table[full_table['poli_numbers'].isin(keep_samples.index)]

# %%
test_column = 'mortality'
overall_mean = subsample_table[test_column].mean()
def compute_squares(value, mean):
    return (value-mean)**2

# %%
SST = subsample_table[test_column].apply(lambda x: compute_squares(x, overall_mean)).sum()
dof = subsample_table.shape[0]

# %%
group_means = subsample_table.groupby('poli_numbers').mean()[test_column]
ssw = []
ssb = []
for party_number in keep_samples.index:
    ssw.append(subsample_table[subsample_table['poli_numbers'] == party_number][test_column].apply(lambda x: 
                                                                compute_squares(x, group_means[party_number])).sum())
    ssb.append(subsample_table[subsample_table['poli_numbers'] == party_number][test_column].apply(lambda x: 
                                                                compute_squares(group_means[party_number], overall_mean)).sum())
SSW = sum(ssw)
SSB = sum(ssb)

# %%
dofb = len(keep_samples.index) - 1
dofw = 0
for i in keep_samples:
    dofw = dofw + i-1

# %%
keep_samples.index
# Out:
# Float64Index([-1.0, 2.5, 3.0, 4.0, 4.5, 5.0, 5.5, 6.0], dtype='float64', name='poli_numbers')

# %%
SSB
# Out:
# 0.010074959118830797

# %%
SSW
# Out:
# 0.22315768784072057

# %%
SSB + SSW
# Out:
# 0.23323264695955137

# %%
# Null Hp: means are the same
# Alternative Hp: means are different
# alpha = 0.05
F_stat = (SSB/dofb)/(SSW/dofw)

# %%
Fc = 2.08 # automate this (scipy)

# %%
F_stat
# Out:
# 0.9351933324213613
